# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from datetime import datetime
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
from api_keys import weather_api_key
# Build query url
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# %%
# Empty lists for the API data
city_name = []
latitude = []
longitude = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country_name = []
date_weather = []

# Set counter
process_num = 1

# Print statements
print(f"Beginning Data Retrieval")
print(f"-----------------------------")

# Loop thru cities
for city in cities: 
    # Try to append values if found except any KeyError results    
    try:
        response = requests.get(f"{url}&q={city}").json()
        city_name.append(response['name'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country_name.append(response['sys']['country'])                  
        # Convert dt UTC values into Month/Day/Year format
        date_weather.append(datetime.fromtimestamp(response['dt']).strftime('%m/%d/%y'))

        print(f"Processing Record {process_num} | {city}")

        process_num = process_num + 1
        # Due to call limits
        time.sleep(1.30)
                            
    except KeyError: 
        print('City not found. Skipping...')
            
print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | lasa
# Processing Record 2 | albany
# Processing Record 3 | de-kastri
# Processing Record 4 | kavieng
# Processing Record 5 | san patricio
# Processing Record 6 | ribeira grande
# Processing Record 7 | naze
# Processing Record 8 | meiningen
# Processing Record 9 | aykino
# Processing Record 10 | lebu
# Processing Record 11 | alice springs
# Processing Record 12 | ballina
# Processing Record 13 | punta arenas
# Processing Record 14 | yellowknife
# Processing Record 15 | arraial do cabo
# Processing Record 16 | busselton
# Processing Record 17 | mountain home
# Processing Record 18 | quthing
# Processing Record 19 | hualmay
# Processing Record 20 | bluff
# Processing Record 21 | khatanga
# Processing Record 22 | komsomolskiy
# Processing Record 23 | lahaina
# Processing Record 24 | dinan
# Processing Record 25 | codrington
# Processing Record 26 | trani
# Processing Record 27 | barrow
# Processing Record 28 | beidao
# Processing Record 29 | port alfred
# Processing Record 30 | statesville
# Processing Record 31 | bambous virieux
# Processing Record 32 | ushuaia
# Processing Record 33 | rikitea
# City not found. Skipping...
# Processing Record 34 | maua
# Processing Record 35 | saskylakh
# Processing Record 36 | puerto ayora
# City not found. Skipping...
# Processing Record 37 | bredasdorp
# Processing Record 38 | severnyy
# Processing Record 39 | ambilobe
# Processing Record 40 | hobyo
# Processing Record 41 | kavaratti
# Processing Record 42 | saint-augustin
# Processing Record 43 | chuy
# Processing Record 44 | severo-kurilsk
# Processing Record 45 | moose factory
# Processing Record 46 | clyde river
# Processing Record 47 | castro
# Processing Record 48 | sioux lookout
# City not found. Skipping...
# Processing Record 49 | horki
# Processing Record 50 | kapaa
# Processing Record 51 | bairiki
# Processing Record 52 | bethel
# Processing Record 53 | wilmington
# Processing Record 54 | oktyabrskiy
# Processing Record 55 | atuona
# Processing Record 56 | kyaikto
# Processing Record 57 | las cruces
# Processing Record 58 | ereymentau
# Processing Record 59 | ulladulla
# Processing Record 60 | upernavik
# Processing Record 61 | baft
# Processing Record 62 | aksarka
# Processing Record 63 | provideniya
# Processing Record 64 | raahe
# Processing Record 65 | placerville
# Processing Record 66 | phan thiet
# Processing Record 67 | qaanaaq
# City not found. Skipping...
# Processing Record 68 | hasaki
# Processing Record 69 | taksimo
# Processing Record 70 | souillac
# Processing Record 71 | mizdah
# Processing Record 72 | hofn
# Processing Record 73 | vaini
# Processing Record 74 | east london
# Processing Record 75 | tiksi
# City not found. Skipping...
# Processing Record 76 | butaritari
# Processing Record 77 | cape town
# City not found. Skipping...
# Processing Record 78 | georgetown
# Processing Record 79 | kindu
# Processing Record 80 | wanaka
# Processing Record 81 | torbay
# Processing Record 82 | mataura
# Processing Record 83 | sao filipe
# Processing Record 84 | fortuna
# Processing Record 85 | kaitangata
# Processing Record 86 | mandalgovi
# Processing Record 87 | saint-philippe
# Processing Record 88 | namibe
# Processing Record 89 | dabhol
# City not found. Skipping...
# Processing Record 90 | palauig
# Processing Record 91 | chalus
# Processing Record 92 | ilulissat
# Processing Record 93 | dongsheng
# Processing Record 94 | trairi
# Processing Record 95 | sao joao da barra
# Processing Record 96 | hobart
# Processing Record 97 | mandera
# Processing Record 98 | xichang
# Processing Record 99 | bengkulu
# City not found. Skipping...
# Processing Record 100 | yuzhno-kurilsk
# Processing Record 101 | port lincoln
# City not found. Skipping...
# Processing Record 102 | faya
# Processing Record 103 | novoagansk
# Processing Record 104 | russell
# Processing Record 105 | longyearbyen
# Processing Record 106 | ahipara
# Processing Record 107 | karratha
# Processing Record 108 | lompoc
# City not found. Skipping...
# Processing Record 109 | sungaipenuh
# Processing Record 110 | papetoai
# Processing Record 111 | cap malheureux
# Processing Record 112 | louis trichardt
# Processing Record 113 | norman wells
# Processing Record 114 | tasiilaq
# Processing Record 115 | alofi
# Processing Record 116 | haines junction
# Processing Record 117 | aswan
# Processing Record 118 | bubaque
# Processing Record 119 | wajid
# City not found. Skipping...
# Processing Record 120 | qazvin
# Processing Record 121 | narsaq
# Processing Record 122 | atar
# Processing Record 123 | sterling
# Processing Record 124 | nishihara
# Processing Record 125 | lagoa
# Processing Record 126 | paamiut
# Processing Record 127 | santa fe
# Processing Record 128 | kismayo
# Processing Record 129 | susangerd
# Processing Record 130 | iskitim
# Processing Record 131 | ponta do sol
# Processing Record 132 | auki
# Processing Record 133 | grand gaube
# Processing Record 134 | yeppoon
# Processing Record 135 | mount gambier
# Processing Record 136 | north bend
# Processing Record 137 | cadiz
# Processing Record 138 | mackay
# Processing Record 139 | lingao
# Processing Record 140 | geraldton
# Processing Record 141 | tautira
# Processing Record 142 | villa bruzual
# Processing Record 143 | vanimo
# Processing Record 144 | saint george
# Processing Record 145 | bandarbeyla
# Processing Record 146 | tortosa
# City not found. Skipping...
# Processing Record 147 | la asuncion
# Processing Record 148 | shingu
# Processing Record 149 | port elizabeth
# City not found. Skipping...
# Processing Record 150 | tucuman
# Processing Record 151 | mar del plata
# Processing Record 152 | mahebourg
# Processing Record 153 | xai-xai
# Processing Record 154 | hervey bay
# Processing Record 155 | fare
# Processing Record 156 | labuhan
# Processing Record 157 | ayan
# Processing Record 158 | veraval
# Processing Record 159 | carnarvon
# Processing Record 160 | kodiak
# Processing Record 161 | ancud
# Processing Record 162 | warren
# Processing Record 163 | salvador
# City not found. Skipping...
# Processing Record 164 | lityn
# Processing Record 165 | nizwa
# Processing Record 166 | midland
# Processing Record 167 | sokoto
# Processing Record 168 | kenai
# Processing Record 169 | jamestown
# Processing Record 170 | sao miguel do araguaia
# Processing Record 171 | cabo san lucas
# Processing Record 172 | husavik
# Processing Record 173 | kaeo
# Processing Record 174 | vardo
# Processing Record 175 | svetlogorsk
# Processing Record 176 | portland
# Processing Record 177 | fuerte olimpo
# City not found. Skipping...
# Processing Record 178 | chokurdakh
# Processing Record 179 | luderitz
# Processing Record 180 | ribeira brava
# Processing Record 181 | rulenge
# Processing Record 182 | adrar
# Processing Record 183 | port blair
# City not found. Skipping...
# Processing Record 184 | macae
# Processing Record 185 | obidos
# Processing Record 186 | avarua
# Processing Record 187 | la reforma
# Processing Record 188 | erzin
# Processing Record 189 | makokou
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 190 | aklavik
# Processing Record 191 | huarmey
# Processing Record 192 | margate
# Processing Record 193 | guerrero negro
# Processing Record 194 | hermanus
# Processing Record 195 | pangnirtung
# Processing Record 196 | port-gentil
# Processing Record 197 | texarkana
# Processing Record 198 | pailon
# Processing Record 199 | yulara
# Processing Record 200 | benghazi
# Processing Record 201 | fuyang
# Processing Record 202 | carambei
# City not found. Skipping...
# Processing Record 203 | gat
# Processing Record 204 | puerto colombia
# Processing Record 205 | hithadhoo
# Processing Record 206 | shaoguan
# City not found. Skipping...
# Processing Record 207 | limbang
# Processing Record 208 | buchanan
# Processing Record 209 | esperance
# Processing Record 210 | brae
# Processing Record 211 | new norfolk
# Processing Record 212 | plettenberg bay
# Processing Record 213 | hambantota
# Processing Record 214 | arlit
# Processing Record 215 | millington
# Processing Record 216 | lorengau
# Processing Record 217 | ugoofaaru
# Processing Record 218 | katherine
# Processing Record 219 | pemba
# Processing Record 220 | tres arroyos
# Processing Record 221 | kroya
# Processing Record 222 | havre-saint-pierre
# Processing Record 223 | kahului
# Processing Record 224 | apastovo
# Processing Record 225 | westport
# Processing Record 226 | rawson
# Processing Record 227 | sisimiut
# Processing Record 228 | te anau
# Processing Record 229 | carahue
# Processing Record 230 | atambua
# Processing Record 231 | villa carlos paz
# Processing Record 232 | athens
# Processing Record 233 | fairbanks
# Processing Record 234 | si sa ket
# Processing Record 235 | janauba
# Processing Record 236 | port hedland
# Processing Record 237 | liancheng
# City not found. Skipping...
# Processing Record 238 | cherskiy
# Processing Record 239 | kurumkan
# Processing Record 240 | bilma
# City not found. Skipping...
# Processing Record 241 | necochea
# Processing Record 242 | trabzon
# City not found. Skipping...
# Processing Record 243 | yangjiang
# Processing Record 244 | bani walid
# Processing Record 245 | sorong
# Processing Record 246 | nelson bay
# Processing Record 247 | havelock
# Processing Record 248 | ostrovnoy
# City not found. Skipping...
# Processing Record 249 | sambava
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 250 | tuktoyaktuk
# Processing Record 251 | saint anthony
# Processing Record 252 | amapa
# Processing Record 253 | shirokiy
# Processing Record 254 | tazovskiy
# Processing Record 255 | constitucion
# Processing Record 256 | tessalit
# Processing Record 257 | howard springs
# Processing Record 258 | dikson
# Processing Record 259 | lucea
# Processing Record 260 | airai
# Processing Record 261 | tilichiki
# Processing Record 262 | sergeyevka
# Processing Record 263 | nikolskoye
# Processing Record 264 | san andres
# Processing Record 265 | kathu
# Processing Record 266 | isangel
# Processing Record 267 | santa rosa
# Processing Record 268 | palizada
# Processing Record 269 | mount isa
# Processing Record 270 | brest
# Processing Record 271 | hilo
# City not found. Skipping...
# Processing Record 272 | watrous
# Processing Record 273 | roma
# Processing Record 274 | abha
# Processing Record 275 | raga
# Processing Record 276 | talnakh
# Processing Record 277 | pevek
# Processing Record 278 | nuuk
# Processing Record 279 | siocon
# Processing Record 280 | qaqortoq
# Processing Record 281 | comodoro rivadavia
# Processing Record 282 | valparaiso
# Processing Record 283 | mehamn
# Processing Record 284 | seddon
# Processing Record 285 | marzuq
# Processing Record 286 | zaozerne
# Processing Record 287 | nueva loja
# Processing Record 288 | santa catalina
# Processing Record 289 | iqaluit
# Processing Record 290 | wuan
# Processing Record 291 | khilok
# Processing Record 292 | san juan
# Processing Record 293 | curaca
# Processing Record 294 | nizhniy tsasuchey
# Processing Record 295 | marsaxlokk
# Processing Record 296 | mahibadhoo
# City not found. Skipping...
# Processing Record 297 | ust-tsilma
# Processing Record 298 | mahajanga
# Processing Record 299 | vila velha
# Processing Record 300 | kalianget
# Processing Record 301 | mogadishu
# Processing Record 302 | ampanihy
# Processing Record 303 | kiunga
# Processing Record 304 | gamba
# Processing Record 305 | strongsville
# Processing Record 306 | cidreira
# Processing Record 307 | manzhouli
# City not found. Skipping...
# Processing Record 308 | hovd
# Processing Record 309 | pisco
# Processing Record 310 | hamina
# Processing Record 311 | broken hill
# Processing Record 312 | san cristobal
# Processing Record 313 | dingle
# Processing Record 314 | bartica
# Processing Record 315 | atbasar
# Processing Record 316 | kloulklubed
# Processing Record 317 | walvis bay
# Processing Record 318 | san vicente
# City not found. Skipping...
# Processing Record 319 | emmett
# Processing Record 320 | myitkyina
# Processing Record 321 | panjab
# Processing Record 322 | nouadhibou
# Processing Record 323 | kruisfontein
# Processing Record 324 | kamaishi
# Processing Record 325 | chapada dos guimaraes
# Processing Record 326 | mawlaik
# Processing Record 327 | am timan
# Processing Record 328 | klaksvik
# Processing Record 329 | merke
# Processing Record 330 | hamilton
# City not found. Skipping...
# Processing Record 331 | ovalle
# Processing Record 332 | andenes
# Processing Record 333 | kidal
# Processing Record 334 | oranjemund
# Processing Record 335 | galle
# Processing Record 336 | phalaborwa
# Processing Record 337 | stockholm
# Processing Record 338 | camacha
# Processing Record 339 | bondoukou
# Processing Record 340 | acajutla
# Processing Record 341 | lincoln
# Processing Record 342 | sabzevar
# Processing Record 343 | tabory
# Processing Record 344 | vasto
# Processing Record 345 | praia
# Processing Record 346 | lipin bor
# Processing Record 347 | yantal
# Processing Record 348 | birin
# Processing Record 349 | porto de moz
# Processing Record 350 | zhuhai
# Processing Record 351 | namtsy
# Processing Record 352 | male
# Processing Record 353 | elko
# Processing Record 354 | rosa zarate
# Processing Record 355 | coffs harbour
# Processing Record 356 | otane
# Processing Record 357 | saurimo
# Processing Record 358 | sola
# Processing Record 359 | pandoh
# Processing Record 360 | paita
# Processing Record 361 | namatanai
# City not found. Skipping...
# Processing Record 362 | zlitan
# Processing Record 363 | sangueya
# Processing Record 364 | ola
# Processing Record 365 | ayagoz
# Processing Record 366 | morondava
# Processing Record 367 | salmas
# Processing Record 368 | thompson
# City not found. Skipping...
# Processing Record 369 | sobolevo
# Processing Record 370 | ossora
# City not found. Skipping...
# Processing Record 371 | zykovo
# Processing Record 372 | bushehr
# Processing Record 373 | iroquois falls
# Processing Record 374 | ornskoldsvik
# Processing Record 375 | morant bay
# Processing Record 376 | cayenne
# Processing Record 377 | puerto escondido
# Processing Record 378 | zabid
# Processing Record 379 | victoria
# Processing Record 380 | opuwo
# Processing Record 381 | caravelas
# Processing Record 382 | koforidua
# Processing Record 383 | tepetzintla
# Processing Record 384 | kamyshlov
# Processing Record 385 | udachnyy
# Processing Record 386 | mumbwa
# Processing Record 387 | robertsport
# Processing Record 388 | pacific grove
# Processing Record 389 | vagamo
# Processing Record 390 | la palma
# Processing Record 391 | roberval
# Processing Record 392 | santa barbara
# Processing Record 393 | waddan
# Processing Record 394 | magnor
# Processing Record 395 | muros
# Processing Record 396 | mareeba
# Processing Record 397 | rubizhne
# Processing Record 398 | banda aceh
# Processing Record 399 | rioblanco
# Processing Record 400 | acari
# Processing Record 401 | stanger
# Processing Record 402 | yorosso
# Processing Record 403 | tupiza
# Processing Record 404 | winchester
# Processing Record 405 | kampot
# Processing Record 406 | acarau
# Processing Record 407 | bac lieu
# Processing Record 408 | togul
# Processing Record 409 | turayf
# Processing Record 410 | baruun-urt
# Processing Record 411 | vilhena
# Processing Record 412 | hornepayne
# Processing Record 413 | zhanaozen
# Processing Record 414 | korla
# Processing Record 415 | shenkursk
# Processing Record 416 | chara
# Processing Record 417 | kajaani
# Processing Record 418 | srednekolymsk
# Processing Record 419 | palmas bellas
# Processing Record 420 | scituate
# Processing Record 421 | itaueira
# Processing Record 422 | kalmunai
# City not found. Skipping...
# Processing Record 423 | pali
# Processing Record 424 | puerto lempira
# Processing Record 425 | asau
# Processing Record 426 | moron
# Processing Record 427 | qeshm
# Processing Record 428 | ust-nera
# Processing Record 429 | stornoway
# Processing Record 430 | krk
# Processing Record 431 | barcelos
# Processing Record 432 | middelburg
# Processing Record 433 | eyl
# Processing Record 434 | piacabucu
# Processing Record 435 | kailua
# Processing Record 436 | tual
# Processing Record 437 | ilo
# Processing Record 438 | broome
# Processing Record 439 | sumbe
# Processing Record 440 | olinda
# Processing Record 441 | lodja
# Processing Record 442 | maldonado
# Processing Record 443 | goroka
# Processing Record 444 | pucallpa
# Processing Record 445 | muborak
# Processing Record 446 | neiafu
# Processing Record 447 | shima
# Processing Record 448 | igrim
# Processing Record 449 | lavrentiya
# Processing Record 450 | villamontes
# Processing Record 451 | nikolayevsk-na-amure
# Processing Record 452 | shihezi
# Processing Record 453 | faanui
# Processing Record 454 | civitavecchia
# Processing Record 455 | graciano sanchez
# City not found. Skipping...
# Processing Record 456 | nizhnyaya omka
# Processing Record 457 | verkhoyansk
# Processing Record 458 | verkhnevilyuysk
# Processing Record 459 | ono
# Processing Record 460 | egvekinot
# Processing Record 461 | padang
# Processing Record 462 | kieta
# Processing Record 463 | firminy
# Processing Record 464 | sayyan
# Processing Record 465 | sydney
# Processing Record 466 | buala
# Processing Record 467 | mustang
# Processing Record 468 | nanortalik
# Processing Record 469 | makakilo city
# Processing Record 470 | brookings
# Processing Record 471 | rusape
# Processing Record 472 | sibolga
# Processing Record 473 | jilib
# Processing Record 474 | taquari
# Processing Record 475 | sobral
# Processing Record 476 | proletariy
# Processing Record 477 | tuatapere
# Processing Record 478 | zhigansk
# Processing Record 479 | harper
# Processing Record 480 | waitati
# Processing Record 481 | coihaique
# Processing Record 482 | sept-iles
# Processing Record 483 | taoudenni
# Processing Record 484 | meadow lake
# Processing Record 485 | kilindoni
# Processing Record 486 | bud
# City not found. Skipping...
# Processing Record 487 | tommot
# Processing Record 488 | coquimbo
# Processing Record 489 | dalvik
# Processing Record 490 | palmer
# Processing Record 491 | carauari
# Processing Record 492 | cockburn town
# Processing Record 493 | fandriana
# Processing Record 494 | candeias
# Processing Record 495 | berdigestyakh
# Processing Record 496 | moerai
# City not found. Skipping...
# Processing Record 497 | chojnice
# Processing Record 498 | petropavlovsk-kamchatskiy
# Processing Record 499 | toul
# Processing Record 500 | paramonga
# Processing Record 501 | yubari
# Processing Record 502 | jalu
# Processing Record 503 | college
# Processing Record 504 | vestmanna
# Processing Record 505 | derzhavinsk
# Processing Record 506 | loikaw
# Processing Record 507 | tabou
# City not found. Skipping...
# Processing Record 508 | toppenish
# Processing Record 509 | farah
# Processing Record 510 | kazerun
# Processing Record 511 | bardiyah
# Processing Record 512 | leeton
# Processing Record 513 | agucadoura
# Processing Record 514 | saint-pierre
# Processing Record 515 | nha trang
# Processing Record 516 | priargunsk
# Processing Record 517 | road town
# Processing Record 518 | mashhad
# Processing Record 519 | marks
# City not found. Skipping...
# Processing Record 520 | ndele
# Processing Record 521 | camocim
# Processing Record 522 | dudinka
# Processing Record 523 | akyab
# Processing Record 524 | batagay
# Processing Record 525 | ocampo
# Processing Record 526 | wasilla
# Processing Record 527 | singapore
# Processing Record 528 | los llanos de aridane
# Processing Record 529 | delray beach
# Processing Record 530 | chikmagalur
# Processing Record 531 | nuevo progreso
# Processing Record 532 | kayerkan
# City not found. Skipping...
# Processing Record 533 | yar-sale
# Processing Record 534 | keti bandar
# Processing Record 535 | thatcham
# Processing Record 536 | port hueneme
# Processing Record 537 | rio gallegos
# Processing Record 538 | clarence town
# Processing Record 539 | poshekhonye
# Processing Record 540 | poum
# Processing Record 541 | surt
# Processing Record 542 | sinnamary
# Processing Record 543 | carutapera
# Processing Record 544 | jardim
# Processing Record 545 | vuktyl
# Processing Record 546 | maniitsoq
# Processing Record 547 | kodinar
# City not found. Skipping...
# Processing Record 548 | newport
# City not found. Skipping...
# Processing Record 549 | vao
# Processing Record 550 | rajula
# Processing Record 551 | taltal
# Processing Record 552 | vestmannaeyjar
# Processing Record 553 | atasu
# City not found. Skipping...
# Processing Record 554 | ust-barguzin
# Processing Record 555 | souris
# Processing Record 556 | misasi
# Processing Record 557 | holme
# Processing Record 558 | ashcroft
# Processing Record 559 | patna
# Processing Record 560 | evensk
# Processing Record 561 | baherden
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Check how many results came out from Openweathermap out of the city list obtained from citipy
cities_retrieved = len(city_name)
print(f"A total of {cities_retrieved} cities with weather data was obtained for analysis")
# Out:
# A total of 561 cities with weather data was obtained for analysis

# %%
# Display Data frame with column units based on Openweathermap documentations
raw_data = {'City':city_name, 'Latitude': latitude, 'Longitude': longitude,
              'MaxTemp (°C)': max_temp, 'Humidity (%)': humidity, 'Cloudiness (%)': cloudiness,
              'WindSpeed (meter/sec)': wind_speed, 'Country': country_name, 'Date': date_weather}

weather_df = pd.DataFrame(raw_data)
weather_df.head()
# Out:
#            City  Latitude  Longitude  MaxTemp (°C)  Humidity (%)  \
# 0          Laas     46.62      10.70          8.00            87
# 1        Albany     42.60     -73.97         20.00            72
# 2     De-Kastri     51.47     140.78          8.60            92
# 3       Kavieng     -2.57     150.80         29.92            68
# 4  San Patricio     19.22    -104.70         26.49            64
#
#    Cloudiness (%)  WindSpeed (meter/sec) Country      Date
# 0              40                   3.60      IT  06/18/20
# 1              63                   0.88      US  06/18/20
# 2             100                   3.19      RU  06/18/20
# 3              27                   3.71      PG  06/18/20
# 4              17                   1.31      MX  06/18/20

# %%
# Check each columns' value count & if there's any NaN values
print(weather_df.count())
print(weather_df.isna().sum())
# Out:
# City                     561
# Latitude                 561
# Longitude                561
# MaxTemp (°C)             561
# Humidity (%)             561
# Cloudiness (%)           561
# WindSpeed (meter/sec)    561
# Country                  561
# Date                     561
# dtype: int64
# City                     0
# Latitude                 0
# Longitude                0
# MaxTemp (°C)             0
# Humidity (%)             0
# Cloudiness (%)           0
# WindSpeed (meter/sec)    0
# Country                  0
# Date                     0
# dtype: int64

# %%
# Export data to csv 
weather_df.to_csv('../output_data/weather_data.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Refer to a Statistic Summary Data then Check for the maximum humidity value
weather_df.describe()
# Out:
#          Latitude   Longitude  MaxTemp (°C)  Humidity (%)  Cloudiness (%)  \
# count  561.000000  561.000000    561.000000    561.000000      561.000000
# mean    18.496791   17.083619     20.533226     66.994652       45.167558
# std     33.782078   90.511162      8.191038     23.285073       39.267495
# min    -54.800000 -179.170000     -5.000000      3.000000        0.000000
# 25%    -10.070000  -63.600000     15.000000     54.000000        1.000000
# 50%     21.050000   23.700000     21.950000     72.000000       40.000000
# 75%     48.520000   95.320000     26.480000     85.000000       88.000000
# max     78.220000  176.630000     40.440000    100.000000      100.000000
#
#        WindSpeed (meter/sec)
# count             561.000000
# mean                3.780499
# std                 2.504226
# min                 0.090000
# 25%                 1.930000
# 50%                 3.100000
# 75%                 5.100000
# max                14.450000

# %%
Max_humidity = weather_df['Humidity (%)'].max()
print(f"The maximum humidity value in the data set is equal to {Max_humid},")
print(f"there are no cities with > 100% humidity to remove.")
# Out:
# The maximum humidity value in the data set is equal to 100,
# there are no cities with > 100% humidity to remove.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
weather_date = weather_df['Date'][0]
plt.scatter(weather_df['Latitude'], weather_df['MaxTemp (°C)'], marker='o',color='r', edgecolor='m', alpha=0.5, s=30)
plt.title(f"Figure 1: City Latitude vs Max Temperature  {weather_date}")
plt.xlabel(f"Latitude")
plt.ylabel(f"Temp (Celcius)")
plt.grid(True)
plt.savefig('../output_data/Fig1_LatitudeVsTemperature.png')
plt.show()

# %% [markdown]
# ## Analysis
#
# Figure 1 illustrates that the city's locations are situated somewhere between the latitude range of -60° at the South Pole and +80° at the North Pole of the Equator.
#
# According to the National Geographic channel, there's a relationship between temperature and latitude around the world, as temperatures are typically warmer approaching the Equator. There are variations, though, as other factors such as elevation, ocean currents, and precipitation will still affect climate patterns.
#
# The graphical plots depict a curve form rather than a straight line. It supports the variations brought about by other factors affecting climate patterns. One variable does not increase at a constant rate and may even start decreasing at a certain point.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
weather_date = weather_df['Date'][0]
plt.scatter(weather_df['Latitude'],weather_df['Humidity (%)'],marker='o',color='orange',edgecolor='y', alpha=0.5, s=30)
plt.title(f"Figure 2: City Latitude vs Humidity  {weather_date}")
plt.xlabel(f"Latitude")
plt.ylabel(f"Humidity(%)")
plt.grid(True)
plt.savefig('../output_data/Fig2_LatitudeVsHumidity.png')
plt.show()

# %% [markdown]
# ## Analysis
#
# Figure 2 illustrates that humidity does not correlate strongly with latitude. The plots are scattered mostly between 60% to around 90% humidity readings.
#
# It is believed that when relative humidity reaches 100%, the air is totally saturated with water vapor and more likely to rain.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
weather_date = weather_df['Date'][0]
plt.scatter(weather_df['Latitude'],weather_df['Cloudiness (%)'],marker='o',color='lightskyblue',edgecolor='b', alpha=0.5, s=30)
plt.title(f"Figure 3: City Latitude vs Cloudiness  {weather_date}")
plt.xlabel(f"Latitude")
plt.ylabel(f"Cloudiness (%)")
plt.grid(True)
plt.savefig('../output_data/Fig3_LatitudeVsCloudiness.png')
plt.show()

# %% [markdown]
# ## Analysis
#
# Figure 3 illustrates that cloudiness rate does not have any correlation with latitude. But it appears to have colletion points at along 0%, 75% and 100% readings.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
weather_date = weather_df['Date'][0]
plt.scatter(weather_df['Latitude'],weather_df['WindSpeed (meter/sec)'],marker='o',color='grey',edgecolor='black', alpha=0.5, s=30)
plt.title(f"Figure 4: City Latitude vs Wind Speed  {weather_date}")
plt.xlabel(f"Latitude")
plt.ylabel(f"Wind Speed(meter/sec)")
plt.grid(True)
plt.savefig('../output_data/Fig4_LatitudeVsWindspeed.png')
plt.show()

# %% [markdown]
# ## Analysis
#
# Figure 4 illustrates that wind speed does not have any correlation with latitude.
#
# Regardless of the city's latitude., it shows that the speed of wind has been going at 0-5 meters/sec rate at the time the information was collected.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.8271188905041935

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.39936284758885965

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10829462153873139

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.0008996079328825663

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.05768812657005063

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.0684912094859049

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.023371104533850804

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.03381889207758188
